# %% [markdown]
# # Deep Learning: Charity Funding Predictor
#
# ## Contributor: Sam Espe
#
# ### Step 3: Optimizing the Model - Attempt 1
#
#
# For this optimization attempt, I am going to try making the "Other" categories in the Application_Type and Classification columns larger. My thought is that by reducing the number of input parameters slightly, the model will be able to become a little more accurate.

# %% [markdown]
# Reading in data and model

# %%
# Import dependencies

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
# Read in charity_data.csv


application_df = pd.read_csv('https://charity-funding-data-set.s3.us-east-2.amazonaws.com/charity_data.csv')
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load in the saved model from the .h5 file

optimization_1_model = tf.keras.models.load_model("/content/gdrive/MyDrive/Data Visualization & Analysis Boot Camp/Deep-Learning-Charity-Funding/Original Neural Network Model/AlphabetSoupCharity.h5")

# %%
optimization_1_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 150)               7050
#
#  dense_1 (Dense)             (None, 150)               22650
#
#  dense_2 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 29,851
# Trainable params: 29,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Pre-Process the Data

# %%
# Split off IS_SUCCESSFUL (target) from the feature variables
y = application_df["IS_SUCCESSFUL"]
X = application_df.drop(columns= "IS_SUCCESSFUL")

# %%
# Remove unnecessary columns (EIN & NAME)
X = X.drop(columns= ["EIN", "NAME"])

# %%
# Find distribution of unique values of Application Type
X["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Save the value counts series

app_type = X["APPLICATION_TYPE"].value_counts()

# %%
# Turn the series into a dictionary

app_dict = app_type.to_dict()

# %%
# If the application type has fewer than 100 instances, add it to the list of low-frequency application types.

small_apps = []

for key, value in app_dict.items():
  if int(value) < 200:
    small_apps.append(key)

# %%
# If an entry in the Application Type column of the dataframe contains an application type that is in the low-frequency list, replace the value with "Other".

for line in range(len(X)):
    if X.iloc[line, 0] in small_apps:
        X.iloc[line, 0] = "Other"

# %%
# Find the distribution of unique values of Classification

X["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Save the value counts of the unique classifications

classes = X["CLASSIFICATION"].value_counts()

# %%
# Turn the series into a dictionary

classes_dict = classes.to_dict()

# %%
# If the class has fewer than 200 instances, add the class to the list of low-frequency classes.

small_classes = []

for key, value in classes_dict.items():
    if int(value) < 500:
        small_classes.append(key)

# %%
# If an entry in the Classification column of the dataframe contains a classification that is in the low-frequency list, replace the value with "Other".

for line in range(len(X)):
    if X.iloc[line, 2] in small_classes:
        X.iloc[line, 2] = "Other"

# %%
# One-hot encode categorical variables (Application Type, Classification, Use Case, Organizaton Type, Income Amt, Special Considerations)

X_encoded_df = pd.get_dummies(X)

# %%
# The Special Considerations column was encoded twice: once where Y was encoded as 1, and once where N was encoded as 1. I am removing the column where N was encoded as 1 to
# avoid having duplicate data.

X_dummies = X_encoded_df.drop(columns = "SPECIAL_CONSIDERATIONS_N")

# %%
# Split data set into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X_encoded_df, y, random_state = 7)

# %%
# Scale the data

scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #### Create the Neural Network

# %%
# Create Keras sequential model

optimization_1_model = tf.keras.models.Sequential()

# %%
# Create the input layer 

optimization_1_model.add(tf.keras.layers.Dense(units = 150, activation = "relu", input_dim = 44))

# %%
# Create first hidden layer

optimization_1_model.add(tf.keras.layers.Dense(units = 150, activation = "relu"))

# %%
# Create output layer

optimization_1_model.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

# %%
optimization_1_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 150)               6750
#
#  dense_4 (Dense)             (None, 150)               22650
#
#  dense_5 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 29,551
# Trainable params: 29,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimization_1_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
# Fit the model to the training set

fit_model = optimization_1_model.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 5ms/step - loss: 0.5680 - accuracy: 0.7233
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5548 - accuracy: 0.7285
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5519 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7319
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5481 - accuracy: 0.7323
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7344
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5462 - accuracy: 0.7334
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5458 - accuracy: 0.7336
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5446 - accuracy: 0.7346
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7355
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7338
# Epoch 12/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5437 - accuracy: 0.7351
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7362
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7355
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5420 - accuracy: 0.7356
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5416 - accuracy: 0.7358
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7367
# Epoch 18/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5403 - accuracy: 0.7368
# Epoch 19/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5402 - accuracy: 0.7368
# Epoch 20/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5397 - accuracy: 0.7372
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5399 - accuracy: 0.7370
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5392 - accuracy: 0.7379
# Epoch 23/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5398 - accuracy: 0.7377
# Epoch 24/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5390 - accuracy: 0.7377
# Epoch 25/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5389 - accuracy: 0.7385
# Epoch 26/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5384 - accuracy: 0.7387
# Epoch 27/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5382 - accuracy: 0.7384
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5378 - accuracy: 0.7400
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7385
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7393
# Epoch 31/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5374 - accuracy: 0.7388
# Epoch 32/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5374 - accuracy: 0.7383
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5368 - accuracy: 0.7396
# Epoch 34/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5367 - accuracy: 0.7399
# Epoch 35/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5366 - accuracy: 0.7390
# Epoch 36/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5360 - accuracy: 0.7396
# Epoch 37/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5358 - accuracy: 0.7399
# Epoch 38/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.7403
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7383
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5355 - accuracy: 0.7399
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5355 - accuracy: 0.7403
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7404
# Epoch 43/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5350 - accuracy: 0.7406
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7405
# Epoch 45/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5352 - accuracy: 0.7406
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5348 - accuracy: 0.7397
# Epoch 47/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5344 - accuracy: 0.7406
# Epoch 48/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5347 - accuracy: 0.7398
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7404
# Epoch 50/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5346 - accuracy: 0.7407
# Epoch 51/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7409
# Epoch 52/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7404
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7407
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7413
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5339 - accuracy: 0.7409
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7406
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7409
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7406
# Epoch 59/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 60/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7405
# Epoch 61/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7408
# Epoch 62/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5336 - accuracy: 0.7411
# Epoch 63/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5336 - accuracy: 0.7414
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7409
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5335 - accuracy: 0.7412
# Epoch 67/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5324 - accuracy: 0.7411
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.7409
# Epoch 69/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7414
# Epoch 70/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5330 - accuracy: 0.7416
# Epoch 71/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5337 - accuracy: 0.7409
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7410
# Epoch 74/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7410
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7413
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7408
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7415
# Epoch 78/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5326 - accuracy: 0.7415
# Epoch 79/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7419
# Epoch 80/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5319 - accuracy: 0.7409
# Epoch 81/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5330 - accuracy: 0.7412
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7419
# Epoch 83/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5323 - accuracy: 0.7414
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7414
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7405
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7418
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7410
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7411
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7407
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7409
# Epoch 92/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7418
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7410
# Epoch 94/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7407
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7407
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7410
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7423
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7414
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7415

# %%
# Evaluate the model using the testing data

model_loss, model_accuracy = optimization_1_model.evaluate(X_test_scaled, y_test, verbose = 2)

print(f'Loss: {round(model_loss * 100, 2)}%, Accuracy: {round(model_accuracy * 100, 2)}%')
# Out:
# 268/268 - 1s - loss: 0.5793 - accuracy: 0.7272 - 517ms/epoch - 2ms/step
# Loss: 57.93%, Accuracy: 72.72%

# %%
# Export results to HDF5 file: Alphabet_Soup_Charity_Optimization_1.h5
optimization_1_model.save("Alphabet_Soup_Charity_Optimization_1.h5")

# %% [markdown]
# The original model had an accuracy of 72.73% and a loss of 58.55%. This model had an accuracy of 72.72% and a loss of 57.93%. This model did about the same as the original.
